# %% [markdown]
# # Datetime conversion to format for SQL query

# %%
# Set the UK timezone (GMT or UTC)
uk_timezone = pytz.timezone("Europe/London")

# Get the current datetime in UK timezone & format in specific way
current_datetime = datetime.now(uk_timezone)
formatted_datetime = current_datetime.strftime("%d-%m-%Y %H%M")

# %% [markdown]
# # Connection to SQL server with trustswervercertificate = true set in case of error

# %%
table_df = (spark.read.format("jdbc")
                       .option("url", db_conn_str)
                       .option("query", f"SELECT {concatenated_fields} FROM [" + schema + "].[" + table_name + "] With (NoLock)")
                       .option("user", sql_username)
                       .option("password", sql_password)
                       .option("driver", "com.microsoft.sqlserver.jdbc.SQLServerDriver")
                       >>>>.option("trustServerCertificate", "true")<<<<
                       .load())
